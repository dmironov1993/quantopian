# %% [markdown]
# # Exercises: Linear Correlation Analysis
#
# ## Lecture Link :
# https://www.quantopian.com/lectures/linear-correlation-analysis
#
# ###IMPORTANT NOTE:
# This lecture corresponds to the Linear Correlation Analysis lecture, which is part of the Quantopian lecture series. This homework expects you to rely heavily on the code presented in the corresponding lecture. Please copy and paste regularly from that lecture when starting to work on the problems, as trying to do them from scratch will likely be too difficult.
#
# Part of the Quantopian Lecture Series:
#
# * [www.quantopian.com/lectures](https://www.quantopian.com/lectures)
# * [github.com/quantopian/research_public](https://github.com/quantopian/research_public)
#
# ----

# %% [markdown]
# ## Key Concepts

# %%
# Useful Functions
def find_most_correlated(data):
    n = data.shape[1]
    keys = data.keys()
    pair = []
    max_value = 0
    for i in range(n):
        for j in range(i+1, n):
            S1 = data[keys[i]]
            S2 = data[keys[j]]
            result = np.corrcoef(S1, S2)[0,1]
            if result > max_value:
                pair = (keys[i], keys[j])
                max_value = result
    return pair, max_value

# %%
# Useful Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# # Exercise 1: Dependence of Artificial Variables
#
# ## a. Finding Variance, Covariance, and Correlation I
#
# By reading the matrix output from the `np.cov()` and `np.corrcoef()` functions, find the variance of the variables $A$ and $B$ and the covariance and correlation of their relationship.

# %%
A = np.random.rand(100)
B = -3 * A + np.random.exponential(0.05, 100)

#Your code goes here
cov_matrix = np.cov(A,B)
print "Covariance matrix: \n", cov_matrix, "\n"
print "Variance of A: ", cov_matrix[0,0]
print "Variance of B: ", cov_matrix[1,1]
print "Covariance of A and B: ", cov_matrix[0,1], "\n"
print "Correlation (np.cov) of A and B: ", np.cov(A,B)[0,1]/(np.std(A, ddof=1)*np.std(B, ddof=1)), "\n"
print "Correlation (np.corrcoef) of A and B: ", np.corrcoef(A,B)[0,1]
# Out:
# Covariance matrix:
# [[ 0.08309451 -0.24669837]
#  [-0.24669837  0.74028805]]
#
# Variance of A:  0.0830945070856
# Variance of B:  0.740288045612
# Covariance of A and B:  -0.246698373021
#
# Correlation (np.cov) of A and B:  -0.994671694137
#
# Correlation (np.corrcoef) of A and B:  -0.994671694137

# %%
assert round(np.cov(A,B)[0,1]/(np.std(A, ddof=1)*np.std(B, ddof=1)),6) == round(np.corrcoef(A,B)[0,1],6)

# %%
print "Variance (np.var) of A: ", np.var(A, ddof=1)
print "Variance (np.var) of B: ", np.var(B, ddof=1)
# Out:
# Variance (np.var) of A:  0.0830945070856
# Variance (np.var) of B:  0.740288045612

# %%
assert round(cov_matrix[0,0],6) == round(np.var(A, ddof=1),6)
assert round(cov_matrix[1,1],6) == round(np.var(B, ddof=1),6)

# %% [markdown]
# Let's plot the relationship between A and B.

# %%
plt.scatter(A,B)
plt.xlabel("A")
plt.ylabel("B")
plt.show()

# %% [markdown]
# ## b. Finding Variance, Covariance, and Correlation II
#
# By reading the matrix output from the `np.cov()` and `np.corrcoef()` functions, find the variance of the variables $C$ and $D$ and the covariance and correlation of their relationship.

# %%
C = np.random.rand(100)
D = np.random.normal(0, 0.5, 100)

#Your code goes here
cov_matrix = np.cov(C,D)
print "Covariance matrix: \n", cov_matrix, "\n"
print "Variance of C: ", cov_matrix[0,0]
print "Variance of D: ", cov_matrix[1,1]
print "Covariance of C and D: ", cov_matrix[0,1], "\n"
print "Correlation (np.cov) of C and D: ", np.cov(C,D)[0,1]/(np.std(C, ddof=1)*np.std(D, ddof=1)), "\n"
print "Correlation (np.corrcoef) of C and D: ", np.corrcoef(C,D)[0,1]
# Out:
# Covariance matrix:
# [[ 0.09129528  0.00070443]
#  [ 0.00070443  0.24285677]]
#
# Variance of C:  0.0912952829889
# Variance of D:  0.242856766521
# Covariance of C and D:  0.000704432934919
#
# Correlation (np.cov) of C and D:  0.0047308630799
#
# Correlation (np.corrcoef) of C and D:  0.0047308630799

# %%
assert round(np.cov(C,D)[0,1]/(np.std(C, ddof=1)*np.std(D, ddof=1)),6) == round(np.corrcoef(C,D)[0,1],6)

# %%
print "Variance (np.var) of C: ", np.var(C, ddof=1)
print "Variance (np.var) of D: ", np.var(D, ddof=1)
# Out:
# Variance (np.var) of C:  0.0912952829889
# Variance (np.var) of D:  0.242856766521

# %%
assert round(cov_matrix[0,0],6) == round(np.var(C, ddof=1),6)
assert round(cov_matrix[1,1],6) == round(np.var(D, ddof=1),6)

# %% [markdown]
# Let's plot the relationship between C and D.

# %%
plt.scatter(C,D)
plt.xlabel("A")
plt.ylabel("B")
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # Exercise 2: Constructing Example Relationships
#
# ## a. Positive Correlation Example
#
# Construct a variable $Y$ which has a strong, but not perfect, positive correlation with $X$ $(0.9 < Corr(X,Y) < 1)$, and plot their relationship.

# %%
X = np.random.rand(100)

#Your code goes here
Y = X + np.random.normal(0,0.1,100)

# %%
print "Correlation of X and Y: ", np.corrcoef(X,Y)[0,1]
# Out:
# Correlation of X and Y:  0.945509021762

# %%
plt.scatter(X,Y)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ## b. Negative Correlation Example
#
# Construct a variable $W$ which has a weak, negative correlation with $Z$ $(-0.3 < Corr(Z,W) < 0)$, and plot their relationship.

# %%
Z = np.random.rand(100)

#Your code goes here
W = - Z + np.random.exponential(2, 100)

# %%
print "Correlation between Z and W: ", np.corrcoef(Z,W)[0,1]
# Out:
# Correlation between Z and W:  -0.293671678222

# %%
plt.scatter(Z,W)
plt.xlabel("Z")
plt.ylabel("W")
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # Exercise 3: Correlation of Real Assets
#
# ## a. Finding Correlation of Real Assets
#
# Find the correlation between the stocks OKE and LAKE. Also check how they correlate with the provided benchmark.

# %%
OKE = get_pricing('OKE', fields='price', start_date='2013-01-01', end_date='2015-01-01')
LAKE = get_pricing('LAKE', fields='price', start_date='2013-01-01', end_date='2015-01-01')
benchmark = get_pricing('SPY', fields='price', start_date='2013-01-01', end_date='2015-01-01')

#Your code goes here
print "Correlation of OKE and LAKE:       ", np.corrcoef(OKE, LAKE)[0,1]
print "Correlation of OKE and benchmark:  ", np.corrcoef(OKE, benchmark)[0,1]
print "Correlation of LAKE and benchmark: ", np.corrcoef(LAKE, benchmark)[0,1]
# Out:
# Correlation of OKE and LAKE:        0.446484870844
# Correlation of OKE and benchmark:   0.853638499475
# Correlation of LAKE and benchmark:  0.625923407419

# %% [markdown]
# ## b. Finding Correlated Pairs
#
# Find the most correlated pair of stocks in the following portfolio using 2015 pricing data and the `find_most_correlated` function defined in the Helper Functions section above.

# %%
symbol_list = ['GSK', 'SNOW', 'FB', 'AZO', 'XEC', 'AMZN']
data = get_pricing(symbol_list, fields=['price']
                               , start_date='2015-01-01', end_date='2016-01-01')['price']
data.columns = symbol_list

#Your code goes here
print "Most correlated pair of stocks: ", find_most_correlated(data)
# Out:
# Most correlated pair of stocks:  (('FB', 'AMZN'), 0.95751089566007552)

# %% [markdown]
# ----

# %% [markdown]
# # Exercise 4: Limitations of Correlation
#
# ## a. Out of Sample Tests
#
# Using pricing data from the first half of 2016, find the correlation coefficient between FB and AMZN and compare it to the strong positive relationship predicted from the 2015 correlation coefficient to see if that result holds.

# %%
FB_15 = get_pricing('FB', fields='price', start_date='2015-01-01', end_date='2016-01-01')
AMZN_15 = get_pricing('AMZN', fields='price', start_date='2015-01-01', end_date='2016-01-01')
FB_16 = get_pricing('FB', fields='price', start_date='2016-01-01', end_date='2016-07-01')
AMZN_16 = get_pricing('AMZN', fields='price', start_date='2016-01-01', end_date='2016-07-01')

#Your code goes here
print "Correlation between FB and AMZN in the first half of 2016: ", np.corrcoef(FB_16, AMZN_16)[0,1]
print "Correlation between FB and AMZN in 2015                  : ", np.corrcoef(FB_15, AMZN_15)[0,1]
# Out:
# Correlation between FB and AMZN in the first half of 2016:  0.651288727673
# Correlation between FB and AMZN in 2015                  :  0.95751089566

# %% [markdown]
# ## b. Rolling Correlation
#
# Plot the 60-day rolling correlation coefficient between FB and AMZN to make a conclusion about the stability of their relationship.

# %%
FB = get_pricing('FB', fields='price', start_date='2015-01-01', end_date='2017-01-01')
AMZN = get_pricing('AMZN', fields='price', start_date='2015-01-01', end_date='2017-01-01')

#Your code goes here
rolling_correlation = pd.rolling_corr(FB, AMZN, window=60)
plt.plot(rolling_correlation)
plt.title("Rolling correlation in a 60-day window")
plt.xlabel("Date")
plt.ylabel("60-day rolling correlation")
plt.show()
# Out:
# /venvs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_corr is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=60).corr(other=<Series>)
#   """

# %%
print "Correlation of FB and AMZN changes significantly over considered period of time"
# Out:
# Correlation of FB and AMZN changes significantly over considered period of time

# %% [markdown]
# Congratulations on completing the Linear Correlation Analysis exercises!
#
# As you learn more about writing trading models and the Quantopian platform, enter a daily [Quantopian Contest](https://www.quantopian.com/contest). Your strategy will be evaluated for a cash prize every day.
#
# Start by going through the [Writing a Contest Algorithm](https://www.quantopian.com/tutorials/contest) tutorial.

# %% [markdown]
# *This presentation is for informational purposes only and does not constitute an offer to sell, a solicitation to buy, or a recommendation for any security; nor does it constitute an offer to provide investment advisory or other services by Quantopian, Inc. ("Quantopian"). Nothing contained herein constitutes investment advice or offers any opinion with respect to the suitability of any security, and any views expressed herein should not be taken as advice to buy, sell, or hold any security or as an endorsement of any security or company.  In preparing the information contained herein, Quantopian, Inc. has not taken into account the investment needs, objectives, and financial circumstances of any particular investor. Any views expressed and data illustrated herein were prepared based upon information, believed to be reliable, available to Quantopian, Inc. at the time of publication. Quantopian makes no guarantees as to their accuracy or completeness. All information is subject to change and may quickly become unreliable for various reasons, including changes in market conditions or economic circumstances.*
